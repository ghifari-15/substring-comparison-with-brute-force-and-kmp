# %%
import timeit

# %%
def brute_force_search(text, pattern):
    """
    Algoritma Brute Force untuk pencarian substring
    """
    n, m = len(text), len(pattern)
    comparisons = 0
    
    for i in range(n - m + 1):
        for j in range(m):
            comparisons += 1
            if text[i + j] != pattern[j]:
                break
        else:
            return i, comparisons
    
    return -1, comparisons

# %%
def kmp_search(text, pattern):
    """
    Algoritma Knuth-Morris-Pratt untuk pencarian substring
    """
    def compute_lps(pattern):
        """
        Membuat Longest Proper Prefix which is also Suffix (LPS)
        """
        m = len(pattern)
        lps = [0] * m
        length = 0
        i = 1
        comparisons = 0
        
        while i < m:
            comparisons += 1
            if pattern[i] == pattern[length]:
                length += 1
                lps[i] = length
                i += 1
            else:
                if length != 0:
                    length = lps[length - 1]
                else:
                    lps[i] = 0
                    i += 1
        
        return lps, comparisons
    
    n, m = len(text), len(pattern)
    lps, prefix_comparisons = compute_lps(pattern)
    
    i = j = comparisons = 0
    while i < n:
        comparisons += 1
        if pattern[j] == text[i]:
            i += 1
            j += 1
        
        if j == m:
            return i - j, comparisons + prefix_comparisons
        
        elif i < n and pattern[j] != text[i]:
            if j != 0:
                j = lps[j - 1]
            else:
                i += 1
    
    return -1, comparisons + prefix_comparisons

# %%
def measure_performance(text, pattern, iterations):
    """
    Mengukur performa dan efisiensi algoritma dengan beberapa iterasi
    """
    bf_times = []
    kmp_times = []
    bf_comparisons = []
    kmp_comparisons = []
    
    for i in range(iterations):
        bf_execution_time = timeit.timeit(lambda: brute_force_search(text, pattern), number=1)
        kmp_execution_time = timeit.timeit(lambda: kmp_search(text, pattern), number=1)
        
        bf_times.append(bf_execution_time)
        kmp_times.append(kmp_execution_time)
        
        bf_result, bf_comparison = brute_force_search(text, pattern)
        kmp_result, kmp_comparison = kmp_search(text, pattern)
        
        bf_comparisons.append(bf_comparison)
        kmp_comparisons.append(kmp_comparison)
        
        # Tampilkan hasil setiap iterasi
        print(f"\nIterasi ke-{i + 1}:")
        print(f"Brute Force - Waktu Eksekusi: {bf_execution_time:.8f} detik, Jumlah Perbandingan: {bf_comparison}")
        print(f"KMP - Waktu Eksekusi: {kmp_execution_time:.8f} detik, Jumlah Perbandingan: {kmp_comparison}")
    
    bf_avg_time = sum(bf_times) / iterations
    kmp_avg_time = sum(kmp_times) / iterations
    bf_avg_comparisons = sum(bf_comparisons) / iterations
    kmp_avg_comparisons = sum(kmp_comparisons) / iterations
    
    # Cetak hasil rata-rata
    print("\n--- Hasil Analisis Pencarian Substring ---")
    print(f"Teks Asli: {text}")
    print(f"Substring Dicari: {pattern}")
    print(f"\nJumlah Iterasi: {iterations}")
    print("\nBrute Force:")
    print(f"Waktu Eksekusi Rata-rata: {bf_avg_time:.8f} detik")
    print(f"Jumlah Perbandingan Rata-rata: {bf_avg_comparisons}")
    
    print("\nKnuth-Morris-Pratt (KMP):")
    print(f"Waktu Eksekusi Rata-rata: {kmp_avg_time:.8f} detik")
    print(f"Jumlah Perbandingan Rata-rata: {kmp_avg_comparisons}")
    
    # Perbandingan
    print("\nPerbandingan Efisiensi:")
    if bf_avg_time < kmp_avg_time:
        print("Brute Force lebih cepat")
    elif kmp_avg_time < bf_avg_time:
        print("KMP lebih cepat")
    else:
        print("Kedua algoritma memiliki waktu eksekusi hampir sama")
    
    print(f"\nSelisih Waktu Eksekusi Rata-rata: {abs(bf_avg_time - kmp_avg_time):.8f} detik")
    print(f"Selisih Jumlah Perbandingan Rata-rata: {abs(bf_avg_comparisons - kmp_avg_comparisons)}")

# %%
def main():
    print("=== Analisis Perbandingan Algoritma Pencarian Substring ===")
    
    # Input dari pengguna
    text = 'word.txt'
    pattern = input("Masukkan substring yang ingin dicari: ")
    iterations = int(input("Masukkan jumlah iterasi yang diinginkan: "))
    
    # Lakukan pengukuran
    measure_performance(text, pattern, iterations)

# %%
# Jalankan program
main()
# Out:
# === Analisis Perbandingan Algoritma Pencarian Substring ===
#
# Iterasi ke-1:
# Brute Force - Waktu Eksekusi: 0.00001330 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001410 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-2:
# Brute Force - Waktu Eksekusi: 0.00000970 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001160 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-3:
# Brute Force - Waktu Eksekusi: 0.00001020 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001110 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-4:
# Brute Force - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000950 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-5:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000900 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-6:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-7:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-8:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-10:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-11:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-12:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-13:
# Brute Force - Waktu Eksekusi: 0.00001140 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001400 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-14:
# Brute Force - Waktu Eksekusi: 0.00001150 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001370 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-15:
# Brute Force - Waktu Eksekusi: 0.00001150 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001040 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-16:
# Brute Force - Waktu Eksekusi: 0.00000790 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000990 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-17:
# Brute Force - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000920 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-18:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-19:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-20:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000900 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-21:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-22:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-23:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-24:
# Brute Force - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001050 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-25:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-26:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-27:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-28:
# Brute Force - Waktu Eksekusi: 0.00002890 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-29:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-30:
# Brute Force - Waktu Eksekusi: 0.00001300 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-31:
# Brute Force - Waktu Eksekusi: 0.00001250 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001180 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-32:
# Brute Force - Waktu Eksekusi: 0.00001180 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001260 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-33:
# Brute Force - Waktu Eksekusi: 0.00001700 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001120 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-34:
# Brute Force - Waktu Eksekusi: 0.00001220 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000970 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-35:
# Brute Force - Waktu Eksekusi: 0.00001100 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001180 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-36:
# Brute Force - Waktu Eksekusi: 0.00001340 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001380 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-37:
# Brute Force - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001100 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-38:
# Brute Force - Waktu Eksekusi: 0.00001200 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001470 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-39:
# Brute Force - Waktu Eksekusi: 0.00001240 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001510 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-40:
# Brute Force - Waktu Eksekusi: 0.00001350 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001510 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-41:
# Brute Force - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-42:
# Brute Force - Waktu Eksekusi: 0.00000790 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-43:
# Brute Force - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000960 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-44:
# Brute Force - Waktu Eksekusi: 0.00001180 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-45:
# Brute Force - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000900 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-46:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-47:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-48:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-49:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-50:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-51:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-52:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-53:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-54:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-55:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-56:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-57:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-58:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-59:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-60:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-61:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-62:
# Brute Force - Waktu Eksekusi: 0.00000700 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-63:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-64:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-65:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-66:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-67:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-68:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-69:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-70:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-71:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-72:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-73:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-74:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-75:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-76:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-77:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-78:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001030 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-79:
# Brute Force - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000940 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-80:
# Brute Force - Waktu Eksekusi: 0.00000770 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-81:
# Brute Force - Waktu Eksekusi: 0.00001220 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-82:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-83:
# Brute Force - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-84:
# Brute Force - Waktu Eksekusi: 0.00000770 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-85:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-86:
# Brute Force - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-87:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-88:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-89:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-90:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-91:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-92:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-93:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001480 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-94:
# Brute Force - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-95:
# Brute Force - Waktu Eksekusi: 0.00000770 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-96:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-97:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-98:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-99:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-100:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-101:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-102:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-103:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-104:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-105:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-106:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-107:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-108:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-109:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-110:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-111:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-112:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-113:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-114:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-115:
# Brute Force - Waktu Eksekusi: 0.00025880 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001020 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-116:
# Brute Force - Waktu Eksekusi: 0.00000780 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000890 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-117:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-118:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-119:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-120:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-121:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-122:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-123:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-124:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-125:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-126:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-127:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-128:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-129:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001290 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-130:
# Brute Force - Waktu Eksekusi: 0.00000700 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000790 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-131:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-132:
# Brute Force - Waktu Eksekusi: 0.00001210 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001240 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-133:
# Brute Force - Waktu Eksekusi: 0.00001180 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001270 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-134:
# Brute Force - Waktu Eksekusi: 0.00001070 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-135:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-136:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001030 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-137:
# Brute Force - Waktu Eksekusi: 0.00000790 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000890 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-138:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-139:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-140:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-141:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-142:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-143:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-144:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-145:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-146:
# Brute Force - Waktu Eksekusi: 0.00000770 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-147:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-148:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-149:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-150:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-151:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-152:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-153:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-154:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-155:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000890 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-156:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-157:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-158:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-159:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-160:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-161:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-162:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-163:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-164:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-165:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-166:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-167:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-168:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-169:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-170:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-171:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-172:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-173:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-174:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-175:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-176:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-177:
# Brute Force - Waktu Eksekusi: 0.00000780 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-178:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-179:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-180:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-181:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001190 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-182:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001360 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-183:
# Brute Force - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-184:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-185:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-186:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-187:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-188:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-189:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-190:
# Brute Force - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-191:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-192:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-193:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-194:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-195:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-196:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-197:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-198:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-199:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-200:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-201:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-202:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-203:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-204:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-205:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-206:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-207:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-208:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-209:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-210:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-211:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-212:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-213:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-214:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000990 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-215:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-216:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-217:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-218:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-219:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-220:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-221:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-222:
# Brute Force - Waktu Eksekusi: 0.00001380 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000990 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-223:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-224:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-225:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-226:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-227:
# Brute Force - Waktu Eksekusi: 0.00001250 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001460 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-228:
# Brute Force - Waktu Eksekusi: 0.00000920 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000980 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-229:
# Brute Force - Waktu Eksekusi: 0.00001170 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001010 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-230:
# Brute Force - Waktu Eksekusi: 0.00001090 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001340 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-231:
# Brute Force - Waktu Eksekusi: 0.00001210 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000900 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-232:
# Brute Force - Waktu Eksekusi: 0.00000780 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001210 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-233:
# Brute Force - Waktu Eksekusi: 0.00001080 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-234:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-235:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-236:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-237:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-238:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-239:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-240:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-241:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-242:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-243:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-244:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-245:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-246:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-247:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001280 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-248:
# Brute Force - Waktu Eksekusi: 0.00001220 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001280 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-249:
# Brute Force - Waktu Eksekusi: 0.00001170 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001130 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-250:
# Brute Force - Waktu Eksekusi: 0.00001150 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001210 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-251:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-252:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-253:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-254:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000890 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-255:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-256:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-257:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-258:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-259:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-260:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-261:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-262:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-263:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-264:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-265:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-266:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-267:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-268:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-269:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-270:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-271:
# Brute Force - Waktu Eksekusi: 0.00000710 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-272:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-273:
# Brute Force - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-274:
# Brute Force - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000940 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-275:
# Brute Force - Waktu Eksekusi: 0.00000780 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-276:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001340 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-277:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-278:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-279:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-280:
# Brute Force - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000940 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-281:
# Brute Force - Waktu Eksekusi: 0.00000770 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-282:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-283:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-284:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-285:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-286:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-287:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-288:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-289:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-290:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-291:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-292:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-293:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-294:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-295:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-296:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-297:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-298:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-299:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-300:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-301:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-302:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-303:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-304:
# Brute Force - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-305:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-306:
# Brute Force - Waktu Eksekusi: 0.00001130 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-307:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-308:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-309:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-310:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-311:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-312:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-313:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-314:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# ...
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9901:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9902:
# Brute Force - Waktu Eksekusi: 0.00001110 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9903:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9904:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001130 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9905:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9906:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9907:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9908:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9909:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9910:
# Brute Force - Waktu Eksekusi: 0.00000930 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9911:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9912:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9913:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9914:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9915:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9916:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9917:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9918:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9919:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9920:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9921:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9922:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9923:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9924:
# Brute Force - Waktu Eksekusi: 0.00001240 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001390 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9925:
# Brute Force - Waktu Eksekusi: 0.00000900 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000900 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9926:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9927:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9928:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9929:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000920 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9930:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9931:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9932:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9933:
# Brute Force - Waktu Eksekusi: 0.00000960 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9934:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9935:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9936:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9937:
# Brute Force - Waktu Eksekusi: 0.00000920 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9938:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9939:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9940:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9941:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9942:
# Brute Force - Waktu Eksekusi: 0.00000790 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001050 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9943:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9944:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9945:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9946:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9947:
# Brute Force - Waktu Eksekusi: 0.00000890 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000960 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9948:
# Brute Force - Waktu Eksekusi: 0.00000760 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000860 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9949:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9950:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9951:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9952:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9953:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9954:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9955:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9956:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9957:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9958:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9959:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9960:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9961:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9962:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9963:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9964:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9965:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9966:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9967:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9968:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9969:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9970:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9971:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9972:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000810 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9973:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9974:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9975:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9976:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9977:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9978:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9979:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9980:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9981:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9982:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9983:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9984:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9985:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9986:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9987:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9988:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9989:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9990:
# Brute Force - Waktu Eksekusi: 0.00000730 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000820 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9991:
# Brute Force - Waktu Eksekusi: 0.00000740 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000850 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9992:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000840 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9993:
# Brute Force - Waktu Eksekusi: 0.00000720 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000830 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9994:
# Brute Force - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000960 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9995:
# Brute Force - Waktu Eksekusi: 0.00000800 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000870 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9996:
# Brute Force - Waktu Eksekusi: 0.00000770 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000910 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9997:
# Brute Force - Waktu Eksekusi: 0.00000780 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001580 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9998:
# Brute Force - Waktu Eksekusi: 0.00001320 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00001200 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-9999:
# Brute Force - Waktu Eksekusi: 0.00001370 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000950 detik, Jumlah Perbandingan: 56
#
# Iterasi ke-10000:
# Brute Force - Waktu Eksekusi: 0.00000750 detik, Jumlah Perbandingan: 54
# KMP - Waktu Eksekusi: 0.00000880 detik, Jumlah Perbandingan: 56
#
# --- Hasil Analisis Pencarian Substring ---
# Teks Asli: trekstekstejswhsbdhwbawhdbashdjdsbjdsbjdbjsahjsabdeuiy
# Substring Dicari: uiy
#
# Jumlah Iterasi: 10000
#
# Brute Force:
# Waktu Eksekusi Rata-rata: 0.00000855 detik
# Jumlah Perbandingan Rata-rata: 54.0
#
# Knuth-Morris-Pratt (KMP):
# Waktu Eksekusi Rata-rata: 0.00000969 detik
# Jumlah Perbandingan Rata-rata: 56.0
#
# Perbandingan Efisiensi:
# Brute Force lebih cepat
#
# Selisih Waktu Eksekusi Rata-rata: 0.00000115 detik
# Selisih Jumlah Perbandingan Rata-rata: 2.0
